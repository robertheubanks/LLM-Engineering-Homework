# %% [markdown]
# <a href="https://colab.research.google.com/github/robertheubanks/LLM-Engineering-Homework/blob/main/Eubanks_Week3_Assignment5_%233_Copy_of_Model_Evaluation_Instruct_tuned_Mistral_7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ⚠ IMPORTANT ⚠
#
# Please ensure your Colab runtime is set to the following:
#
# A100 GPU
#
# Evaluation and instruction-tuning a LLM is a resource intensive process - please make sure you're using the appropriate instance.

# %% [markdown]
# # Evaluating an Instruct-tuned Model
#
# Now that we've spent some time creating models with:
#
# - Unsupervised pre-training
# - Supervised fine-tuning
# - Some instruction-tuning
#
# We're ready to begin to think about how we can evaluate these models.

# %% [markdown]
# ## Instruct-tuned Evaluation
#
# We will now repeat the process we used on our baseline - but using the instruct-tuned version of our model!

# %% [markdown]
# ### Load Mistral AI's Mistral-7B in 4-bit Quantization
#
# Let's grab our dependencies, and load our model!

# %%
# !pip install -qU bitsandbytes datasets accelerate loralib peft transformers trl
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 38.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 35.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 87.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.9/150.9 kB 22.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.7/79.7 kB 12.0 MB/s eta 0:00:00

# %%
import torch
import torch.nn as nn
import bitsandbytes as bnb
from transformers import AutoTokenizer, AutoConfig, AutoModelForCausalLM, BitsAndBytesConfig

# %% [markdown]
# Conforming to previous notebooks - let's set up our quantization config for our model.

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
)

# %% [markdown]
# Now we have our quantization settings confirmed - let's load up our model!

# %%
model_id = "mistralai/Mistral-7B-Instruct-v0.2"

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map='auto',
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %% [markdown]
# ####❓ Question:
#
# Taking a look at the [model card](https://huggingface.co/mistralai/Mistral-7B-v0.1) (and the linked resources on the card) is this an instruct-tuned model or not?

# %% [markdown]
# ANSWER:
# this is an instruct-tuned variant of Mistral 7B. The base model itself is designed for high performance and can be fine-tuned for specific tasks, including instruction following. The specific mention of "Mistral 7B Instruct" being fine-tuned on instruction datasets and outperforming other models in instruction-following benchmarks strongly indicates that this variant is indeed an instruct-tuned model.

# %% [markdown]
# ### Collect and Load the Eleuther AI Evaluation Harness
#
# Now that we have our baseline model loaded - we need to evaluate it.
#
# For that, we'll use a tool called [Eleuther AI's LM evaluation harness](https://github.com/EleutherAI/lm-evaluation-harness). This is a specialized tool for running benchmarks on various language tasks.
#
# Let's start by grabbing and installing it!
#
# Why Eleuther AI's Evaluation Harness? Well - it's what powers the [Open LLM Leaderboard](https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard)!

# %%
# !git clone https://github.com/EleutherAI/lm-evaluation-harness
# %cd lm-evaluation-harness
# !pip install -e .
# Out:
# Cloning into 'lm-evaluation-harness'...
# remote: Enumerating objects: 30525, done.
# remote: Counting objects: 100% (1008/1008), done.
# remote: Compressing objects: 100% (467/467), done.
# remote: Total 30525 (delta 664), reused 828 (delta 537), pack-reused 29517
# Receiving objects: 100% (30525/30525), 22.06 MiB | 12.98 MiB/s, done.
# Resolving deltas: 100% (21350/21350), done.
# /content/lm-evaluation-harness
# Obtaining file:///content/lm-evaluation-harness
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.0) (0.26.1)
# Collecting evaluate (from lm_eval==0.4.0)
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.0) (2.16.1)
# Collecting jsonlines (from lm_eval==0.4.0)
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.0) (2.8.8)
# Requirement already satisfied: peft>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.0) (0.7.1)
# Collecting pybind11>=2.6.2 (from lm_eval==0.4.0)
#   Downloading pybind11-2.11.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 12.0 MB/s eta 0:00:00
# Collecting pytablewriter (from lm_eval==0.4.0)
#   Downloading pytablewriter-1.2.0-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 16.7 MB/s eta 0:00:00
# Collecting rouge-score>=0.0.4 (from lm_eval==0.4.0)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm_eval==0.4.0)
#   Downloading sacrebleu-2.4.0-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.0) (1.2.2)
# Collecting sqlitedict (from lm_eval==0.4.0)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.0) (2.1.0+cu121)
# Collecting tqdm-multiprocess (from lm_eval==0.4.0)
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.0) (4.37.1)
# Collecting zstandard (from lm_eval==0.4.0)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 63.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.0) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.0) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.0) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.0) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (3.13.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.0) (3.9.1)
# Collecting responses<0.19 (from evaluate->lm_eval==0.4.0)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.0) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.0) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.0) (1.16.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm_eval==0.4.0)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.0) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.0) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm_eval==0.4.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.0) (4.9.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.0) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.0) (3.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.0) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.0) (2.1.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm_eval==0.4.0) (0.15.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm_eval==0.4.0) (23.2.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.0) (67.7.2)
# Collecting DataProperty<2,>=1.0.1 (from pytablewriter->lm_eval==0.4.0)
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm_eval==0.4.0)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm_eval==0.4.0)
#   Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm_eval==0.4.0)
#   Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm_eval==0.4.0)
#   Downloading tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.3.2 (from pytablewriter->lm_eval==0.4.0)
#   Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval==0.4.0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval==0.4.0) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval==0.4.0) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval==0.4.0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval==0.4.0) (4.0.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.0) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.14.0->lm_eval==0.4.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.14.0->lm_eval==0.4.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.14.0->lm_eval==0.4.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.14.0->lm_eval==0.4.0) (2023.11.17)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.0) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.0) (2023.3.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->lm_eval==0.4.0) (2.1.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==0.4.0) (8.1.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8->lm_eval==0.4.0) (1.3.0)
# Building wheels for collected packages: lm_eval, rouge-score, sqlitedict
#   Building editable for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.0-0.editable-py3-none-any.whl size=13518 sha256=cea5b701c2a34ff39038f3108f12faf6773c843402c2358b68a7c3c80281800a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s79508m3/wheels/dc/8d/a0/ce1a137b6a29fcf5007da91566ee423695e01d20703991091d
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=ae824518fce6a18f1225f5516d169963df51b729faf777140bb474c3b5e8853d
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=3b842baf0f958938b5f5ebb3245f39463db0c83f90cb66a649cc7672d7a7027c
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built lm_eval rouge-score sqlitedict
# Installing collected packages: sqlitedict, zstandard, tcolorpy, pybind11, portalocker, pathvalidate, mbstrdecoder, jsonlines, colorama, typepy, tqdm-multiprocess, sacrebleu, rouge-score, responses, DataProperty, tabledata, evaluate, pytablewriter, lm_eval
# Successfully installed DataProperty-1.0.1 colorama-0.4.6 evaluate-0.4.1 jsonlines-4.0.0 lm_eval-0.4.0 mbstrdecoder-1.1.3 pathvalidate-3.2.0 portalocker-2.8.2 pybind11-2.11.1 pytablewriter-1.2.0 responses-0.18.0 rouge-score-0.1.2 sacrebleu-2.4.0 sqlitedict-2.1.0 tabledata-1.3.3 tcolorpy-0.1.4 tqdm-multiprocess-0.0.11 typepy-1.3.2 zstandard-0.22.0

# %% [markdown]
# Now, we can cast our model to the desired format.

# %%
import lm_eval
from lm_eval.models.huggingface import HFLM
eval_model = HFLM(model, batch_size=16)
# Out:
# Downloading builder script:   0%|          | 0.00/5.67k [00:00<?, ?B/s]
# WARNING:lm-eval:`pretrained` model kwarg is not of type `str`. Many other model arguments may be ignored. Please do not launch via accelerate or use `parallelize=True` if passing an existing model this way.
# WARNING:lm-eval:Passed an already-initialized model through `pretrained`, assuming single-process call to evaluate() or custom distributed integration

# %% [markdown]
# We'll set up our tasks so we can leverage them at evaluation time!

# %%
lm_eval.tasks.initialize_tasks()
# Out:
# WARNING:lm-eval:Some tasks could not be loaded due to missing dependencies. Run with `--verbosity DEBUG` for full details.
# WARNING:lm-eval:Some tasks could not be loaded due to missing dependencies. Run with `--verbosity DEBUG` for full details.

# %% [markdown]
# Next, we can evaluate our base model!
#
# >NOTE: This step will take ~30-40min. to run in full on the A100 - so ensure you set aside time to run it fully if you desire!
#
# We're going to leverage two benchmarks today:
#
# - [HellaSwag](https://rowanzellers.com/hellaswag/)
# - [ARC Easy](https://leaderboard.allenai.org/arc_easy/submissions/get-started)
# - A subset of the [MMLU benchmark](https://paperswithcode.com/dataset/mmlu), focusing only on the `college_mathematics` task.
#
# These are lightweight benchmarks used to "score" models against eachother on the OpenLM leaderboard.
#
# We'll consider a simple average of their scores as the "overall" score of the baseline model.
#
# You could easily extend the number of tasks considered if you wanted to more exactly emulate the Open LLM Leaderboard.

# %%
results = lm_eval.simple_evaluate(
    model=eval_model,
    tasks=["hellaswag", "arc_easy"],
    num_fewshot=0,
    batch_size=16,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1429: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/4.36k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.53k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/6.84k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.1M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.04M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.14M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/39905 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10003 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/10042 [00:00<?, ? examples/s]
# Map:   0%|          | 0/39905 [00:00<?, ? examples/s]
# Map:   0%|          | 0/10042 [00:00<?, ? examples/s]
# Downloading readme:   0%|          | 0.00/9.00k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/331k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/346k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/86.1k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2251 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2376 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/570 [00:00<?, ? examples/s]
# WARNING:lm-eval:Overwriting default num_fewshot of hellaswag from None to 0
# WARNING:lm-eval:Overwriting default num_fewshot of arc_easy from None to 0
# INFO:lm-eval:Building contexts for task on rank 0...
# INFO:lm-eval:Building contexts for task on rank 0...
# INFO:lm-eval:Running loglikelihood requests
# 100%|██████████| 49669/49669 [07:22<00:00, 112.25it/s]

# %%
import pandas as pd

pd.DataFrame(results["results"])
# Out:
#                       hellaswag  arc_easy
# acc,none               0.655845  0.819444
# acc_stderr,none        0.004741  0.007893
# acc_norm,none          0.833201  0.771044
# acc_norm_stderr,none    0.00372  0.008622
# alias                 hellaswag  arc_easy

# %% [markdown]
# ### Few-shot MMLU (Machine Learning)

# %%
fs_mmlu_results = lm_eval.simple_evaluate(
    model=eval_model,
    tasks=["mmlu_flan_n_shot_loglikelihood_machine_learning"],
    num_fewshot=5,
    batch_size=16,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1429: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/5.86k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/166M [00:00<?, ?B/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating dev split: 0 examples [00:00, ? examples/s]
# WARNING:lm-eval:Overwriting default num_fewshot of mmlu_flan_n_shot_loglikelihood_machine_learning from None to 5
# INFO:lm-eval:Building contexts for task on rank 0...
# INFO:lm-eval:Running loglikelihood requests
# 100%|██████████| 448/448 [00:34<00:00, 13.13it/s]

# %%
import pandas as pd

pd.DataFrame(fs_mmlu_results["results"])
# Out:
#                       mmlu_flan_n_shot_loglikelihood_machine_learning
# acc,none                                                     0.482143
# acc_norm,none                                                0.482143
# acc_norm_stderr,none                                         0.047428
# acc_stderr,none                                              0.047428
# alias                 mmlu_flan_n_shot_loglikelihood_machine_learning

# %% [markdown]
# ### Zero-Shot MMLU (Machine Learning)

# %%
zs_mmlu_results = lm_eval.simple_evaluate(
    model=eval_model,
    tasks=["mmlu_flan_n_shot_loglikelihood_machine_learning"],
    num_fewshot=0,
    batch_size=16,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1429: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# WARNING:lm-eval:Overwriting default num_fewshot of mmlu_flan_n_shot_loglikelihood_machine_learning from 5 to 0
# INFO:lm-eval:Building contexts for task on rank 0...
# INFO:lm-eval:Running loglikelihood requests
# 100%|██████████| 448/448 [00:05<00:00, 85.22it/s]

# %%
import pandas as pd

pd.DataFrame(zs_mmlu_results["results"])
# Out:
#                       mmlu_flan_n_shot_loglikelihood_machine_learning
# acc,none                                                     0.482143
# acc_norm,none                                                0.482143
# acc_norm_stderr,none                                         0.047428
# acc_stderr,none                                              0.047428
# alias                 mmlu_flan_n_shot_loglikelihood_machine_learning

# %%
cot_mmlu_results = lm_eval.simple_evaluate(
    model=eval_model,
    tasks=["mmlu_flan_cot_zeroshot_conceptual_physics"],
    num_fewshot=0,
    batch_size=16,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1429: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating dev split: 0 examples [00:00, ? examples/s]
# INFO:lm-eval:num_fewshot has been set to 0 for mmlu_flan_cot_zeroshot_conceptual_physics in its config. Manual configuration will be ignored.
# INFO:lm-eval:Building contexts for task on rank 0...
# INFO:lm-eval:Running generate_until requests
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:392: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# 100%|██████████| 26/26 [00:44<00:00,  1.71s/it]

# %%
import pandas as pd

pd.DataFrame(cot_mmlu_results["results"])
# Out:
#                                mmlu_flan_cot_zeroshot_conceptual_physics
# alias                          mmlu_flan_cot_zeroshot_conceptual_physics
# exact_match,get-answer                                          0.153846
# exact_match_stderr,get-answer                                    0.07216

# %% [markdown]
# ####❓Question:
#
# What *exactly* are these two benchmarks measuring?

# %% [markdown]
# ANSWER:
# exact_match_get-answer indicates the proportion of answers that were exactly correct.
# exact_match_stderr_get-answer representS the standard error of the exact match metric, providing an indication of the variability or confidence in the exact match results.
# These benchmarks are measuring the model's ability to correctly answer questions without any fine-tuning specific to the task (zero-shot), and they provide both the performance metric and its associated standard error for statistical robustness.
